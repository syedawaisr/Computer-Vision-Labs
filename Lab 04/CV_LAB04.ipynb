# %% [markdown]
# ##

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load image
image = cv2.imread('chess board.jpg', cv2.IMREAD_GRAYSCALE)

# Apply edge detection
edges = cv2.Canny(image, 50, 150, apertureSize=3)

# Apply Hough Transform
lines = cv2.HoughLines(edges, 1, np.pi / 180, 200)

# Plot the lines
if lines is not None:
    for rho, theta in lines[:, 0]:
        a = np.cos(theta)
        b = np.sin(theta)
        x0 = a * rho
        y0 = b * rho
        x1 = int(x0 + 1000 * (-b))
        y1 = int(y0 + 1000 * (a))
        x2 = int(x0 - 1000 * (-b))
        y2 = int(y0 - 1000 * (a))
        cv2.line(image, (x1, y1), (x2, y2), (255, 0, 0), 10)

# Display results
plt.figure(figsize=(10, 5))
plt.subplot(121), plt.imshow(cv2.cvtColor(edges, cv2.COLOR_BGR2RGB)), plt.title('Edge Image')
plt.subplot(122), plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB)), plt.title('Hough Transform Result')
plt.show()

# %%
rho
# Out:
# 1.0

# %%
theta
# Out:
# 1.5707964

# %%
# import cv2
# import numpy as np
# from matplotlib import pyplot as plt

# # Load the image
# image_path = "chess board.jpg"
# image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# # Perform edge detection using Canny edge detector
# edges = cv2.Canny(image, 50, 150, apertureSize=3)

# # Perform probabilistic Hough line transform
# lines = cv2.HoughLinesP(edges, 1, np.pi/180, threshold=50, minLineLength=50, maxLineGap=10)

# # Plot the original image, Canny edges, and detected lines
# plt.figure(figsize=(15, 5))
# plt.subplot(1, 3, 1)
# plt.imshow(image, cmap='gray')
# plt.title('Input image')
# plt.axis('off')

# plt.subplot(1, 3, 2)
# plt.imshow(edges, cmap='gray')
# plt.title('Canny edges')
# plt.axis('off')

# plt.subplot(1, 3, 3)
# plt.imshow(edges * 0, cmap='gray')
# for line in lines:
#     x1, y1, x2, y2 = line[0]
#     plt.plot((x1, x2), (y1, y2), color='white')
# plt.title('Probabilistic Hough')
# plt.axis('off')

# plt.tight_layout()
# plt.show()
